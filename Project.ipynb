# %% [markdown]
# <a href="https://colab.research.google.com/github/cereng48/gaih-students-repo-example/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('WELCOME TO THE COMPETITION')
print('GOOD LUCK TO EVERYONE!!!\n')

score=0
num=0 # numbers of correct answers

#First Question

print('The first question is: \n 1895*1894=?\n')
print('Options of question: \nA)100000000215 \nB)8465641531 \nC)54654877 \nD)3589130 \n')

answer=input("Write your answer in terms of A,B,C,D:")

if answer != 'A' and answer != 'B' and answer != 'C' and answer != 'D':
  print('Invalid Answer\n')
elif answer == 'D' :
  print('Correct Answer\n')
  score=score + 10
  num += 1
else:
  print('Wrong Answer!!! Correct answer should be D\n')


  #Second Question
  
print('The second question is:\n What is the first ten digits of pi number after the comma?\n')
print('Options of question: \nA)1415926535 \nB)8465641531 \nC)1254654877 \nD)3589130\n')

answer=input("Write your answer in terms of A,B,C,D:")

if answer != 'A' and answer != 'B' and answer != 'C' and answer != 'D':
  print('Invalid Answer\n')
elif answer == 'A' :
  print('Correct Answer\n')
  score=score + 10
  num += 1
else:
  print('Wrong Answer!!! Correct answer should be A\n') 

  #Third Question
  
print('The third question is:\n What is the capital of Turkey?\n')
print('Options of question: \nA)Istanbul \nB)Ankara \nC)İzmir \nD)Antalya\n')

answer=input("Write your answer in terms of A,B,C,D:")

if answer != 'A' and answer != 'B' and answer != 'C' and answer != 'D':
  print('Invalid Answer\n')
elif answer == 'B' :
  print('Correct Answer\n')
  score=score + 10
  num += 1
else:
  print('Wrong Answer!!! Correct answer should be B\n') 

  #Fourth Question
  
print('The fourth question is: \nWhich of the following is the planet with its largest satellite?\n')
print('Options of question: \nA)Pluto \nB)Earth \nC)Venus \nD)Jupiter\n')

answer=input("Write your answer in terms of A,B,C,D:")

if answer != 'A' and answer != 'B' and answer != 'C' and answer != 'D':
  print('Invalid Answer\n')
elif answer == 'D' :
  print('Correct Answer\n')
  score=score + 10
  num += 1
else:
  print('Wrong Answer!!! Correct answer should be D\n') 
  
  #Fifth Question
  
print('The fifth question is: \nWhich country is famous for its tulips?\n')
print('Options of question: \nA)Holland \nB)Turkey \nC)USA \nD)Iranian\n')

answer=input("Write your answer in terms of A,B,C,D:")

if answer != 'A' and answer != 'B' and answer != 'C' and answer != 'D':
  print('Invalid Answer\n')
elif answer == 'A' :
  print('Correct Answer\n')
  score=score + 10
  num += 1
else:
  print('Wrong Answer!!! Correct answer should be A\n') 

  #Sixth Question
  
print('The sixth question is:\n What is the animal that spits when angry?\n')
print('Options of question: \nA)Chameleon \nB)Cow \nC)Lama \nD)Dog\n')

answer=input("Write your answer in terms of A,B,C,D:")

if answer != 'A' and answer != 'B' and answer != 'C' and answer != 'D':
  print('Invalid Answer\n')
elif answer == 'C' :
  print('Correct Answer\n')
  score=score + 10
  num += 1
else:
  print('Wrong Answer!!! Correct answer should be C\n') 
  
    #Seventh Question
  
print('The seventh question is:\n Which of the following was the first domesticated animal?\n')
 
print('Options of question: \nA)Sheep \nB)Dog \nC)Cat \nD)Bird\n')

answer=input("Write your answer in terms of A,B,C,D:")

if answer != 'A' and answer != 'B' and answer != 'C' and answer != 'D':
  print('Invalid Answer\n')
elif answer == 'B' :
  print('Correct Answer\n')
  score=score + 10
  num += 1
else:
  print('Wrong Answer!!! Correct answer should be B\n') 

      #Eighth Question
  
print('The eighth question is: \nWhat is the device that measures the magnitude and duration of the earthquake called?\n')
print('Options of question: \nA)tomograph \nB)simographer \nC)mammograph \nD)compass\n')

answer=input("Write your answer in terms of A,B,C,D:")

if answer != 'A' and answer != 'B' and answer != 'C' and answer != 'D':
  print('Invalid Answer\n')
elif answer == 'B' :
  print('Correct Answer\n')
  score=score + 10
  num += 1
else:
  print('Wrong Answer!!! Correct answer should be B\n') 

      #Ninth Question
  
print('The ninth question is:\n 2*(8+9*5)/(3-5)=?\n')
print('Options of question: \nA)0 \nB)-15 \nC)-53 \nD)2\n')

answer=input("Write your answer in terms of A,B,C,D:")

if answer != 'A' and answer != 'B' and answer != 'C' and answer != 'D':
  print('Invalid Answer\n')
elif answer == 'C' :
  print('Correct Answer\n')
  score=score + 10
  num += 1
else:
  print('Wrong Answer!!! Correct answer should be C\n') 

      #Tenth Question
  
print('The last question is:\n (2850-5+4*3/(5480-944)+(5*2/10))*0=?\n')
print('Options of question: \nA)1 \nB)185 \nC)1450 \nD)0\n')

answer=input("Write your answer in terms of A,B,C,D:")

if answer != 'A' and answer != 'B' and answer != 'C' and answer != 'D':
  print('Invalid Answer\n')
elif answer == 'D' :
  print('Correct Answer\n')
  score=score + 10
  num += 1
else:
  print('Wrong Answer!!! Correct answer should be D\n') 

  
print('Your Total Score:',score)
print('Your Number Of Correct Answers:',num)

if num <= 5:
  print("I'm sorry. You are unsuccessful")
else:
  print("Great!!! You are successful")
# Out:
# WELCOME TO THE COMPETITION
# GOOD LUCK TO EVERYONE!!!
#
# The first question is:
#  1895*1894=?
#
# Options of question:
# A)100000000215
# B)8465641531
# C)54654877
# D)3589130
#
# Write your answer in terms of A,B,C,D:uj
# Invalid Answer
#
# The second question is:
#  What is the first ten digits of pi number after the comma?
#
# Options of question:
# A)1415926535
# B)8465641531
# C)1254654877
# D)3589130
#
# Write your answer in terms of A,B,C,D:A
# Correct Answer
#
# The third question is:
#  What is the capital of Turkey?
#
# Options of question:
# A)Istanbul
# B)Ankara
# C)İzmir
# D)Antalya
#
# Write your answer in terms of A,B,C,D:B
# Correct Answer
#
# The fourth question is:
# Which of the following is the planet with its largest satellite?
#
# Options of question:
# A)Pluto
# B)Earth
# C)Venus
# D)Jupiter
#
# Write your answer in terms of A,B,C,D:D
# Correct Answer
#
# The fifth question is:
# Which country is famous for its tulips?
#
# Options of question:
# A)Holland
# ...
